// %% [markdown]
// # Identity.Com Credential-Commons

// %%
console.log(CCC)
// Out:
// CredentialCommons {
//   Claim:
//    { [Function: Claim]
//      EmailDomain: [Function: UCAConstructor],
//      ContactEmail: [Function: UCAConstructor],
//      UserId: [Function: UCAConstructor],
//      UserRealm: [Function: UCAConstructor],
//      PhoneCountryCode: [Function: UCAConstructor],
//      PhoneNumber: [Function: UCAConstructor],
//      PhoneExtension: [Function: UCAConstructor],
//      PhoneLineType: [Function: UCAConstructor],
//      PhoneNumberCountryCode: [Function: UCAConstructor],
//      PhoneNumberNumber: [Function: UCAConstructor],
//      PhoneNumberExtension: [Function: UCAConstructor],
//      PhoneNumberLineType: [Function: UCAConstructor],
//      ContactPhoneNumber: [Function: UCAConstructor],
//      NameGivenNames: [Function: UCAConstructor],
//      NameFamilyNames: [Function: UCAConstructor],
//      NameOtherNames: [Function: UCAConstructor],
//      TypeName: [Function: UCAConstructor],
//      DocumentName: [Function: UCAConstructor],
// ...
